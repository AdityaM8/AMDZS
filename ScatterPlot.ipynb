# %%
import pandas as pd
import os

# %%
data = pd.read_csv('train.csv')
df = data.copy()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=range(701)
y=range(701)
plt.scatter(x,y,color='red')
plt.title('Scatter Plot of Number vs Random')
plt.xlabel('Number')
plt.ylabel('Random')
plt.show()
